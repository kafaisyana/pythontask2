# %%
import pandas as pd

# %%
energy = pd.read_csv('https://www.stats.govt.nz/assets/Uploads/Environmental-economic-accounts/Environmental-economic-accounts-2020-tables/Download-data/renewable-energy-stock-account-2007-18.csv')

# %%
energy.head()
# Out:
#    year resource        variable           units   magnitude  \
# 0  2007   Biogas   Closing stock         Dollars   Thousands
# 1  2007   Biogas      Generation  Gigawatt hours      Actual
# 2  2007   Biogas  Gigawatt hours          Number  Proportion
# 3  2007   Biogas   Opening stock         Dollars   Thousands
# 4  2007   Biogas   Other changes         Dollars   Thousands
#
#                    source  data_value flag
# 0  Environmental Accounts    86690.00    R
# 1                    MBIE      224.00    F
# 2                    MBIE        0.01    F
# 3  Environmental Accounts         NaN    F
# 4  Environmental Accounts         NaN    F

# %%
energy.tail()
# Out:
#      year resource        variable           units   magnitude  \
# 595  2018     Wood      Generation  Gigawatt hours      Actual
# 596  2018     Wood  Gigawatt hours          Number  Proportion
# 597  2018     Wood   Opening stock         Dollars   Thousands
# 598  2018     Wood   Other changes         Dollars   Thousands
# 599  2018     Wood   Resource rent         Dollars   Thousands
#
#                      source  data_value flag
# 595                    MBIE      301.00    P
# 596                    MBIE        0.01    P
# 597  Environmental Accounts   118567.00    P
# 598  Environmental Accounts   -26061.00    P
# 599  Environmental Accounts     5550.00    P

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 8 columns):
# year          600 non-null int64
# resource      600 non-null object
# variable      600 non-null object
# units         600 non-null object
# magnitude     600 non-null object
# source        600 non-null object
# data_value    586 non-null float64
# flag          600 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 37.6+ KB

# %%
energy.describe()
# Out:
#               year    data_value
# count   600.000000  5.860000e+02
# mean   2012.500000  1.067492e+06
# std       3.454933  3.084908e+06
# min    2007.000000 -2.531163e+06
# 25%    2009.750000  2.325000e+01
# 50%    2012.500000  7.102000e+03
# 75%    2015.250000  1.793882e+05
# max    2018.000000  1.498225e+07

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18,6))

#plt.plot(energy['year'], label = 'year')
plt.plot(energy['magnitude'], label = 'magnitude')
#plt.plot(energy['variable'], label = 'variable')
#plt.plot(energy['units'], label = 'units')
#plt.plot(energy['source'], label = 'source')
plt.plot(energy['flag'], label = 'flag')
plt.plot(energy['resource'], label = 'resource')

#plt.plot(energy['data_value'], label = 'data_value')

plt.xlabel('sumbu x')
plt.ylabel('sumbu y')
plt.title('grafik')
plt.legend();
plt.show()

# %%
plt.plot(energy['data_value'], label = 'data_value')
